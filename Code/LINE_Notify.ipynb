# %%
import requests

# LINE Notify 權杖
token = '2ZXFhYkyhkObm9GB9td6bvyD8ZNEQPqgRImBEVR9u87'

# 要發送的訊息
message = '發送圖片'

# 要傳送的圖片檔案
i = open("/Users/jasonzheng/Desktop/python/213.jpg", 'rb')
f = { 'imageFile': i }

# HTTP 標頭參數與資料
h = { "Authorization": "Bearer " + token }
d = { 'message': message }

# 以 requests 發送 POST 請求
requests.post("https://notify-api.line.me/api/notify",
              headers = h, data = d, files = f)

# %%
pip install line-bot-sdk

# %%
from flask import Flask, request
from linebot import LineBotApi, WebhookHandler
from linebot.models import FlexSendMessage, TextSendMessage, ImageSendMessage, FlexSendMessage

app = Flask(__name__)

# LINE 聊天機器人的基本資料
line_bot_api = LineBotApi('m79AuVEjmnPTs2Lkc72vOCRMSxSod7swCYrfT+OMBbYCMW6Ef6CTmcMuZ5jpc+Ym5dCUoqkBNv1hjj3/zC8DDEjpHbb1eh+BkAmZTsKmN0GdCpILHgPnfg0fUEgy7/uAGR64nP6scjMI17aKuvb5RwdB04t89/1O/w1cDnyilFU=')

@app.route("/verify", methods=['POST'])
def verify():
    data = request.get_json()
    print(data)
#     line_bot_api.reply_message(
#         data['events'][0]['replyToken'],
#         TextSendMessage(text="yee")
#     )

#    if data["events"][0]["message"]["text"]=="DOG":
#         line_bot_api.reply_message(
#             data['events'][0]['replyToken'],
#             ImageSendMessage(original_content_url='https://i.imgur.com/jmLZS7a.jpeg',
#                              preview_image_url='https://i.imgur.com/jmLZS7a.jpeg')
#         )
    line_bot_api.reply_message(
        data['events'][0]['replyToken'],
        FlexSendMessage(alt_text='hello',
                        contents={
  "type": "bubble",
  "hero": {
    "type": "image",
    "url": "https://scdn.line-apps.com/n/channel_devcenter/img/fx/01_1_cafe.png",
    "size": "full",
    "aspectRatio": "20:13",
    "aspectMode": "cover",
    "action": {
      "type": "uri",
      "uri": "http://linecorp.com/"
    }
  },
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "Brown Cafe",
        "weight": "bold",
        "size": "xl"
      },
      {
        "type": "box",
        "layout": "baseline",
        "margin": "md",
        "contents": [
          {
            "type": "icon",
            "size": "sm",
            "url": "https://scdn.line-apps.com/n/channel_devcenter/img/fx/review_gold_star_28.png"
          },
          {
            "type": "icon",
            "size": "sm",
            "url": "https://scdn.line-apps.com/n/channel_devcenter/img/fx/review_gold_star_28.png"
          },
          {
            "type": "icon",
            "size": "sm",
            "url": "https://scdn.line-apps.com/n/channel_devcenter/img/fx/review_gold_star_28.png"
          },
          {
            "type": "icon",
            "size": "sm",
            "url": "https://scdn.line-apps.com/n/channel_devcenter/img/fx/review_gray_star_28.png"
          },
          {
            "type": "text",
            "text": "4.0",
            "size": "sm",
            "color": "#999999",
            "margin": "md",
            "flex": 0
          }
        ]
      },
      {
        "type": "box",
        "layout": "vertical",
        "margin": "lg",
        "spacing": "sm",
        "contents": [
          {
            "type": "box",
            "layout": "baseline",
            "spacing": "sm",
            "contents": [
              {
                "type": "text",
                "text": "Place",
                "color": "#aaaaaa",
                "size": "sm",
                "flex": 1
              },
              {
                "type": "text",
                "text": "Miraina Tower, 4-1-6 Shinjuku, Tokyo",
                "color": "#666666",
                "size": "sm",
                "flex": 5
              }
            ]
          },
          {
            "type": "box",
            "layout": "baseline",
            "spacing": "sm",
            "contents": [
              {
                "type": "text",
                "text": "Time",
                "color": "#aaaaaa",
                "size": "sm",
                "flex": 1
              },
              {
                "type": "text",
                "text": "10:00 - 23:00",
                "color": "#666666",
                "size": "sm",
                "flex": 5
              }
            ]
          }
        ]
      }
    ]
  },
  "footer": {
    "type": "box",
    "layout": "vertical",
    "spacing": "sm",
    "contents": [
      {
        "type": "button",
        "style": "link",
        "height": "sm",
        "action": {
          "type": "uri",
          "label": "CALL",
          "uri": "https://linecorp.com"
        }
      },
      {
        "type": "button",
        "style": "link",
        "height": "sm",
        "action": {
          "type": "uri",
          "label": "WEBSITE",
          "uri": "https://linecorp.com"
        }
      },
      {
        "type": "box",
        "layout": "vertical",
        "contents": [],
        "margin": "sm"
      }
    ],
    "flex": 0
  }
}
                       ))
    return 'OK',200
if __name__ == "__main__":
    app.run(port=6300)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:6300/ (Press CTRL+C to quit)
# {'destination': 'U326ae2a2b1b6412f17134931c0e8e849', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17446146275900', 'text': '123'}, 'webhookEventId': '01GPDAPM8134ZFXJN6QAWFA3DB', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673337196344, 'source': {'type': 'user', 'userId': 'Ua86fac657846d2b437a29c63d5c3d198'}, 'replyToken': 'df686e8eff374a489f669d5140bacbea', 'mode': 'active'}]}
# 127.0.0.1 - - [10/Jan/2023 15:53:17] "POST /verify HTTP/1.1" 200 -
# ...
